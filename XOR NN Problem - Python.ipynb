# %%
#Loading up modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
import datetime

# %%
x = [[0,0],[0,1],[1,0],[1,1]]
y = [0,1,1,0]

# %% [markdown]
# <center><font size="+2">NN #1 (1 hidden layer, 2 nodes)</font></center>

# %%
model1 = keras.models.Sequential([
    keras.layers.Dense(2, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
#setting optimzer and loss function and early callback

optimizer = keras.optimizers.Adam()
loss="binary_crossentropy"
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
#compiling the model

model1.compile(loss=loss,
             optimizer=optimizer,
             metrics=["accuracy"])

# %%
#fitting the model and tracking how long it takes

start = datetime.datetime.now()

model1.fit(x, y, epochs=500, batch_size=4)

end = datetime.datetime.now()

print("Total Time: ", end-start)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 270ms/step - loss: 0.8156 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8145 - accuracy: 0.2500
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8135 - accuracy: 0.2500
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8124 - accuracy: 0.2500
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8114 - accuracy: 0.2500
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8103 - accuracy: 0.2500
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8093 - accuracy: 0.2500
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8083 - accuracy: 0.2500
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8073 - accuracy: 0.2500
# Epoch 10/500
# ...

# %% [markdown]
# <center><font size="+2">NN #2 (1 hidden layer, 8 nodes)</font></center>

# %%
model2 = keras.models.Sequential([
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
#compiling the model

model2.compile(loss=loss,
             optimizer=optimizer,
             metrics=["accuracy"])

# %%
#fitting the model and tracking how long it takes

start = datetime.datetime.now()

model2.fit(x, y, epochs=500, batch_size=4)

end = datetime.datetime.now()

print("Total Time: ", end-start)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.7024 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7016 - accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7000 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6994 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6987 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6981 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.7500
# Epoch 10/500
# ...

# %% [markdown]
# <center><font size="+2">NN #3 (1 hidden layer, 16 nodes)</font></center>

# %%
model3 = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
#compiling the model

model3.compile(loss=loss,
             optimizer=optimizer,
             metrics=["accuracy"])

# %%
#fitting the model and tracking how long it takes

start = datetime.datetime.now()

model3.fit(x, y, epochs=500, batch_size=4)

end = datetime.datetime.now()

print("Total Time: ", end-start)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.6892 - accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6751 - accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6662 - accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6572 - accuracy: 0.7500
# Epoch 10/500
# ...

# %% [markdown]
# <center><font size="+2">NN #3 (1 hidden layer, 32 nodes)</font></center>

# %%
model4 = keras.models.Sequential([
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
#compiling the model

model4.compile(loss=loss,
             optimizer=optimizer,
             metrics=["accuracy"])

# %%
#fitting the model and tracking how long it takes

start = datetime.datetime.now()

model4.fit(x, y, epochs=500, batch_size=4)

end = datetime.datetime.now()

print("Total Time: ", end-start)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.7342 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7302 - accuracy: 0.2500
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7251 - accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7196 - accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7140 - accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7088 - accuracy: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7038 - accuracy: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6990 - accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.2500
# Epoch 10/500
# ...
